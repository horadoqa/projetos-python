# %% [markdown]
# Lógica

# %%
x = 15
y = x - 2
x = y + 9
y = x * 2
z = y - x

print("Qual o resultado da expressão acima, 14, 9, 16 ou 22?")
# print("Resposta: ", z)
# Out:
# Qual o resultado da expressão acima, 14, 9, 16 ou 22?
