# %% [markdown]
# Criando Gráfico com python

# %%
! pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: plotly in /home/rfahham/.local/lib/python3.10/site-packages (6.7.0)
# Requirement already satisfied: narwhals>=1.15.1 in /home/rfahham/.local/lib/python3.10/site-packages (from plotly) (2.20.0)
# Requirement already satisfied: packaging in /home/rfahham/.local/lib/python3.10/site-packages (from plotly) (24.1)

# %%
import plotly.graph_objects as go

# Configurar o renderizador para abrir no navegador
import plotly.io as pio
pio.renderers.default = "browser"

fig = go.Figure(go.Indicator(
    mode="gauge+number",
    value=65,
    title={'text': "Velocidade"},
    gauge={
        'axis': {'range': [0, 100]},  # corrigido aqui
        'bar': {'color': "darkblue"},
        'steps': [
            {'range': [0, 50], 'color': "lightgray"},
            {'range': [50, 100], 'color': "gray"}
        ],
        'threshold': {
            'line': {'color': "red", 'width': 4},
            'thickness': 0.75,
            'value': 90
        }
    }
))

fig.show()
