# %% [markdown]
# Criando Gráfico com python

# %%
! pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting plotly
#   Downloading plotly-6.7.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-2.20.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging in /home/rfahham/.local/lib/python3.10/site-packages (from plotly) (24.1)
# Downloading plotly-6.7.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 8.4 MB/s  0:00:01m0:00:0100:01
# Downloading narwhals-2.20.0-py3-none-any.whl (449 kB)
# Installing collected packages: narwhals, plotly
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [plotly]2m1/2 [plotly]
# Successfully installed narwhals-2.20.0 plotly-6.7.0
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: pip install --upgrade pip

# %%
import plotly.graph_objects as go

# Configurar o renderizador para abrir no navegador
import plotly.io as pio
pio.renderers.default = "browser"

fig = go.Figure(go.Indicator(
    mode="gauge+number",
    value=65,
    title={'text': "Velocidade"},
    gauge={
        'axis': {'range': [0, 100]},  # corrigido aqui
        'bar': {'color': "darkblue"},
        'steps': [
            {'range': [0, 50], 'color': "lightgray"},
            {'range': [50, 100], 'color': "gray"}
        ],
        'threshold': {
            'line': {'color': "red", 'width': 4},
            'thickness': 0.75,
            'value': 90
        }
    }
))

fig.show()
