# %% [markdown]
# # Grouped Workers on AWS

# %%
# using pip (pip3)
! pip install --upgrade pip
! pip install diagrams

# Precisa instalar
# sudo apt install graphviz
# dot -V
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /home/rfahham/.local/lib/python3.10/site-packages (26.0.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: diagrams in /home/rfahham/.local/lib/python3.10/site-packages (0.25.1)
# Requirement already satisfied: graphviz<0.21.0,>=0.13.2 in /home/rfahham/.local/lib/python3.10/site-packages (from diagrams) (0.20.3)
# Requirement already satisfied: jinja2<4.0,>=2.10 in /home/rfahham/.local/lib/python3.10/site-packages (from diagrams) (3.1.4)
# Requirement already satisfied: pre-commit<5,>=4.0.1 in /home/rfahham/.local/lib/python3.10/site-packages (from diagrams) (4.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/rfahham/.local/lib/python3.10/site-packages (from jinja2<4.0,>=2.10->diagrams) (3.0.2)
# Requirement already satisfied: cfgv>=2.0.0 in /home/rfahham/.local/lib/python3.10/site-packages (from pre-commit<5,>=4.0.1->diagrams) (3.5.0)
# Requirement already satisfied: identify>=1.0.0 in /home/rfahham/.local/lib/python3.10/site-packages (from pre-commit<5,>=4.0.1->diagrams) (2.6.16)
# Requirement already satisfied: nodeenv>=0.11.1 in /home/rfahham/.local/lib/python3.10/site-packages (from pre-commit<5,>=4.0.1->diagrams) (1.10.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from pre-commit<5,>=4.0.1->diagrams) (5.4.1)
# Requirement already satisfied: virtualenv>=20.10.0 in /usr/local/lib/python3.10/dist-packages (from pre-commit<5,>=4.0.1->diagrams) (20.27.1)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.10/dist-packages (from virtualenv>=20.10.0->pre-commit<5,>=4.0.1->diagrams) (0.3.9)
# Requirement already satisfied: filelock<4,>=3.12.2 in /usr/local/lib/python3.10/dist-packages (from virtualenv>=20.10.0->pre-commit<5,>=4.0.1->diagrams) (3.16.1)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /home/rfahham/.local/lib/python3.10/site-packages (from virtualenv>=20.10.0->pre-commit<5,>=4.0.1->diagrams) (4.3.2)
# [sudo] password for rfahham:
# sudo: a password is required
# ^C

# %%
from diagrams import Diagram
from diagrams.aws.compute import EC2
from diagrams.aws.database import RDS
from diagrams.aws.network import ELB

with Diagram("Grouped Workers", show=False, direction="TB"):
    ELB("lb") >> [EC2("worker1"),
                  EC2("worker2"),
                  EC2("worker3"),
                  EC2("worker4"),
                  EC2("worker5")] >> RDS("events")
    
print("Arquivo criado com sucesso !!!")
# Out:
# Arquivo criado com sucesso !!!
